# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from geopy.geocoders import Nominatim
import time
import requests
import re

# %%
session = requests.Session()
Agent = 'Mozilla/5.0 (Linux; Android 15; Pixel 9) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/150.0.0.0 Mobile Safari/537.36'
headers = {'User-Agent': Agent}
geolocator = Nominatim(user_agent = Agent, timeout=10)

# %%
df = pd.read_excel('Реестр.xlsx', sheet_name='Лист2')
df.head()
# Out:
#    № п/п                                 Наименование / ФИО      Тип субъекта  \
# 0     20  "КОРПОРАЦИЯ ВИТ" (ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕ...  Юридическое лицо
# 1     52  "ХОЗРАСЧЕТНАЯ СТРОИТЕЛЬНО-ТЕХНОЛОГИЧЕСКАЯ ФИРМ...  Юридическое лицо
# 2   4653                         АКЦИОНЕРНОЕ ОБЩЕСТВО "777"  Юридическое лицо
# 3   4668               АКЦИОНЕРНОЕ ОБЩЕСТВО "АГРОТЕХИМПОРТ"  Юридическое лицо
# 4   4674                         АКЦИОНЕРНОЕ ОБЩЕСТВО "АКС"  Юридическое лицо
#
#              Категория           ОГРН         ИНН  \
# 0    Малое предприятие  1025004907080  5038038838
# 1  Среднее предприятие  1025007270551  5027006369
# 2    Малое предприятие  1021400692048  1414006922
# 3    Малое предприятие  1043301806415  3327332190
# 4    Малое предприятие  1027807999988  7816061297
#
#                     Основной вид деятельности                     Регион  \
# 0  41.20 Строительство жилых и нежилых зданий    50 - Московская область
# 1  41.20 Строительство жилых и нежилых зданий    50 - Московская область
# 2  41.20 Строительство жилых и нежилых зданий              77 - г.Москва
# 3  41.20 Строительство жилых и нежилых зданий  33 - Владимирская область
# 4  41.20 Строительство жилых и нежилых зданий     78 - г.Санкт-Петербург
#
#        Район          Город  ... Дата исключения из реестра Телефон E-mail  \
# 0  Пушкино г            NaN  ...                        NaN     NaN    NaN
# 1        NaN  г Дзержинский  ...                        NaN     NaN    NaN
# 2        NaN            NaN  ...                        NaN     NaN    NaN
# 3        NaN     г Владимир  ...                        NaN     NaN    NaN
# 4        NaN            NaN  ...                        NaN     NaN    NaN
#
#    WWW Наличие лицензий Наличие заключенных договоров, контрактов  \
# 0  NaN              Нет                                       Нет
# 1  NaN               Да                                       Нет
# 2  NaN               Да                                       Нет
# 3  NaN               Да                                       Нет
# 4  NaN               Да                                       Нет
#
#   Производство инновационной, высокотехнологичной продукции  \
# 0                                                Нет
# 1                                                Нет
# 2                                                Нет
# 3                                                Нет
# 4                                                Нет
#
#   Участие в программах партнерства Является социальным предприятием  \
# 0                              Нет                              Нет
# 1                              Нет                              Нет
# 2                              Нет                              Нет
# 3                              Нет                              Нет
# 4                              Нет                              Нет
#
#   Среднесписочная численность работников за предшествующий календарный год
# 0                                               36.0
# 1                                              201.0
# 2                                               35.0
# 3                                               52.0
# 4                                               21.0
#
# [5 rows x 23 columns]

# %%
company_id = pd.DataFrame()
company_id['inn'] = df['ИНН'].dropna().copy()
company_id['id'] = None
company_id
# Out:
#              inn    id
# 0     5038038838  None
# 1     5027006369  None
# 2     1414006922  None
# 3     3327332190  None
# 4     7816061297  None
# ...          ...   ...
# 8922  2301091157  None
# 8923  2301083597  None
# 8924  6504043928  None
# 8925  2002001476  None
# 8926   702005585  None
#
# [8927 rows x 2 columns]

# %%
def parse_id(inn):
    res = session.get(f'https://bo.nalog.gov.ru/advanced-search/organizations/search?query={inn}', headers = headers).json()
    if len(res['content']) > 0:
        return res['content'][0]['id']
    else:
        return None

# %%
company_id['id'] = company_id['inn'].apply(parse_id)
company_id
# Out:
#              inn         id
# 0     5038038838  5872486.0
# 1     5027006369  6900709.0
# 2     1414006922  4980670.0
# 3     3327332190  3867230.0
# 4     7816061297  7041303.0
# ...          ...        ...
# 8922  2301091157  9652105.0
# 8923  2301083597  8043846.0
# 8924  6504043928  7005901.0
# 8925  2002001476  2927552.0
# 8926   702005585   243053.0
#
# [8927 rows x 2 columns]

# %%
company_id = company_id.dropna().astype(int)
company_id
# Out:
#              inn       id
# 0     5038038838  5872486
# 1     5027006369  6900709
# 2     1414006922  4980670
# 3     3327332190  3867230
# 4     7816061297  7041303
# ...          ...      ...
# 8922  2301091157  9652105
# 8923  2301083597  8043846
# 8924  6504043928  7005901
# 8925  2002001476  2927552
# 8926   702005585   243053
#
# [8842 rows x 2 columns]

# %%
def pars_org_data(org_id):
    res = session.get(f'https://bo.nalog.gov.ru/nbo/organizations/{org_id}/bfo/', headers = headers).json()
    if len(res) == 0:
        return 0
    else:
        return res

# %%
def get_EBITA(res, year):
    years_list = [2025, 2024, 2023, 2022, 2021]
        
    if len(res) == 0:
        return non

    if year not in years_list:
        return 0
        
    year_index = years_list.index(year)
    if year_index >= len(res):
        return 0
        
    data = res[year_index]

    type_corrections = data.get('typeCorrections', [])
    if not type_corrections or len(type_corrections) == 0:
        return 0
        
    correction = type_corrections[0].get('correction', {})
    balance = correction.get('balance', {})
    financial = correction.get('financialResult', {})
    
    current1150 = balance.get('current1150', 0)
    previous1150 = balance.get('previous1150', 0)
        
    current1150 = 0 if pd.isna(current1150) else current1150
    previous1150 = 0 if pd.isna(previous1150) else previous1150
        
    amortization = current1150 - previous1150
    
    EBITA = financial.get('current2400', 0) + financial.get('current2410', 0) + financial.get('current2330', 0) + amortization

    return EBITA

# %%
def get_org_EBITA(c_id, years_to_parse):
    res = pars_org_data(c_id)
    return {f'EBITA_{year}': get_EBITA(res, year) for year in years_to_parse}

# %%
company_EBITA = pd.DataFrame()
company_EBITA['name'] = df['Наименование / ФИО'].copy()

cols_apply = ['Регион', 'Город', 'Район']
citys = df[cols_apply].copy()
citys['Регион'] = citys['Регион'].str.split(' - ').str[1]
citys[cols_apply] = citys[cols_apply].apply(lambda x: x.replace(r'^г\.?\s*', '', regex=True).str.strip())
company_EBITA['city'] = citys['Регион'] + ', ' + citys['Город'].combine_first(df['Район'].replace(np.nan, ''))
company_EBITA
# Out:
#                                                    name  \
# 0     "КОРПОРАЦИЯ ВИТ" (ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕ...
# 1     "ХОЗРАСЧЕТНАЯ СТРОИТЕЛЬНО-ТЕХНОЛОГИЧЕСКАЯ ФИРМ...
# 2                            АКЦИОНЕРНОЕ ОБЩЕСТВО "777"
# 3                  АКЦИОНЕРНОЕ ОБЩЕСТВО "АГРОТЕХИМПОРТ"
# 4                            АКЦИОНЕРНОЕ ОБЩЕСТВО "АКС"
# ...                                                 ...
# 8922  СМУ "МОНОЛИТ" (ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТ...
# 8923  СМУ "РУСЬ" (ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕН...
# 8924  СОВМЕСТНОЕ ПРЕДПРИЯТИЕ ОБЩЕСТВО С ОГРАНИЧЕННОЙ...
# 8925  ФИРМА "ТЕПЛОСТРОЙПРОЕКТ-С" ОБЩЕСТВО С ОГРАНИЧЕ...
# 8926  ФИРМА "Ц.М.ХОЛДИНГ" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТ...
#
#                                                city
# 0                     Московская область, Пушкино г
# 1                   Московская область, Дзержинский
# 2                                          Москва,
# 3                    Владимирская область, Владимир
# 4                                 Санкт-Петербург,
# ...                                             ...
# 8922                      Краснодарский край, Анапа
# 8923                      Краснодарский край, Анапа
# 8924                  Сахалинская область, Корсаков
# 8925   Чеченская Республика, Ачхой-Мартановский р-н
# 8926  Кабардино-Балкарская Республика, Зольский р-н
#
# [8927 rows x 2 columns]

# %%
years_to_parse = [2021, 2022, 2023, 2024, 2025]
results = company_id['id'].apply(get_org_EBITA, years_to_parse=years_to_parse)
ebita_df = pd.DataFrame(results.tolist())
ebita_df
# Out:
#       EBITA_2021  EBITA_2022  EBITA_2023  EBITA_2024  EBITA_2025
# 0      -106204.0     -2632.0    -80487.0     -5837.0     68775.0
# 1        72459.0    169330.0   -331305.0    148582.0    878836.0
# 2      -422277.0      1760.0      2695.0     40228.0     15513.0
# 3        34360.0     26469.0     92944.0     69922.0    158698.0
# 4         4460.0     -2662.0      -584.0     21316.0      -349.0
# ...          ...         ...         ...         ...         ...
# 8837    -18673.0    -35527.0    -87702.0    -24430.0      2794.0
# 8838    -22188.0    -39441.0    -29609.0    -25296.0     69516.0
# 8839    121502.0     38881.0   -513174.0   -151461.0    -16205.0
# 8840     -1175.0      3095.0      2134.0     -6130.0      -965.0
# 8841     -1150.0    -10733.0      -538.0     19455.0      1172.0
#
# [8842 rows x 5 columns]

# %%
company_EBITA = pd.concat([company_EBITA, ebita_df], axis=1)
company_EBITA
# Out:
#                                                    name  \
# 0     "КОРПОРАЦИЯ ВИТ" (ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕ...
# 1     "ХОЗРАСЧЕТНАЯ СТРОИТЕЛЬНО-ТЕХНОЛОГИЧЕСКАЯ ФИРМ...
# 2                            АКЦИОНЕРНОЕ ОБЩЕСТВО "777"
# 3                  АКЦИОНЕРНОЕ ОБЩЕСТВО "АГРОТЕХИМПОРТ"
# 4                            АКЦИОНЕРНОЕ ОБЩЕСТВО "АКС"
# ...                                                 ...
# 8922  СМУ "МОНОЛИТ" (ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТ...
# 8923  СМУ "РУСЬ" (ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕН...
# 8924  СОВМЕСТНОЕ ПРЕДПРИЯТИЕ ОБЩЕСТВО С ОГРАНИЧЕННОЙ...
# 8925  ФИРМА "ТЕПЛОСТРОЙПРОЕКТ-С" ОБЩЕСТВО С ОГРАНИЧЕ...
# 8926  ФИРМА "Ц.М.ХОЛДИНГ" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТ...
#
#                                                city  EBITA_2021  EBITA_2022  \
# 0                     Московская область, Пушкино г   -106204.0     -2632.0
# 1                   Московская область, Дзержинский     72459.0    169330.0
# 2                                          Москва,    -422277.0      1760.0
# 3                    Владимирская область, Владимир     34360.0     26469.0
# 4                                 Санкт-Петербург,       4460.0     -2662.0
# ...                                             ...         ...         ...
# 8922                      Краснодарский край, Анапа         NaN         NaN
# 8923                      Краснодарский край, Анапа         NaN         NaN
# 8924                  Сахалинская область, Корсаков         NaN         NaN
# 8925   Чеченская Республика, Ачхой-Мартановский р-н         NaN         NaN
# 8926  Кабардино-Балкарская Республика, Зольский р-н         NaN         NaN
#
#       EBITA_2023  EBITA_2024  EBITA_2025
# 0       -80487.0     -5837.0     68775.0
# 1      -331305.0    148582.0    878836.0
# 2         2695.0     40228.0     15513.0
# 3        92944.0     69922.0    158698.0
# 4         -584.0     21316.0      -349.0
# ...          ...         ...         ...
# 8922         NaN         NaN         NaN
# 8923         NaN         NaN         NaN
# 8924         NaN         NaN         NaN
# 8925         NaN         NaN         NaN
# 8926         NaN         NaN         NaN
#
# [8927 rows x 7 columns]

# %%
company_EBITA = company_EBITA.dropna()
company_EBITA_sortEBITA = company_EBITA.sort_values(['EBITA_2025','EBITA_2024','EBITA_2023','EBITA_2022','EBITA_2021'],ascending=False)
company_EBITA_sortEBITA
# Out:
#                                                    name  \
# 2283  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНКЕ...
# 7595  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УРАЛ...
# 7492  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УДС-...
# 5362  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СПЕЦ...
# 6935  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СТРО...
# ...                                                 ...
# 7823  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦВЕТ...
# 5322  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СПАР...
# 7579  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УРАЛ...
# 2134  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИВДО...
# 8516  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ СПЕЦИ...
#
#                                        city  EBITA_2021  EBITA_2022  \
# 2283                               Москва,    1012961.0     61583.0
# 7595      Челябинская область, Магнитогорск         0.0         0.0
# 7492          Удмуртская Республика, Ижевск         0.0    253582.0
# 5362         Республика Дагестан, Махачкала  -1335209.0    905415.0
# 6935      Свердловская область, Березовский     12317.0     22056.0
# ...                                     ...         ...         ...
# 7823           Республика Башкортостан, Уфа         0.0     73139.0
# 5322                               Москва,    -949041.0    143722.0
# 7579         Челябинская область, Челябинск     14596.0     85570.0
# 2134              Тюменская область, Тюмень      1457.0    -11398.0
# 8516  Республика Марий Эл, Медведевский р-н    281548.0    103275.0
#
#       EBITA_2023  EBITA_2024  EBITA_2025
# 2283      4261.0     23719.0   7061288.0
# 7595         0.0    -10972.0   6041650.0
# 7492   1032553.0   2997677.0   4571887.0
# 5362   1502585.0   -907394.0   3273561.0
# 6935    236411.0    236846.0   3247384.0
# ...          ...         ...         ...
# 7823    239741.0    -19100.0  -1779738.0
# 5322    685440.0   7853405.0  -1899458.0
# 7579     22702.0    348742.0  -2859603.0
# 2134      -391.0      -940.0  -2981463.0
# 8516   1056171.0   1018498.0  -3260916.0
#
# [8842 rows x 7 columns]

# %%
def EBITA_growth (period):
    company_EBITA_growth = company_EBITA.copy()

    N = period
    year_old = 2025 - N  
    year_new = 2025
    EBITA_old = f'EBITA_{year_old}'
    EBITA_new = f'EBITA_{year_new}'
    
    company_EBITA_growth['growth_pct'] = (
    (company_EBITA_growth[EBITA_new] - company_EBITA_growth[EBITA_old]) / company_EBITA_growth[EBITA_old].replace(0, np.nan) * 100)
    company_EBITA_growth = company_EBITA_growth.replace([np.inf, -np.inf], np.nan).dropna()
    company_EBITA_growth['growth_pct'] = company_EBITA_growth['growth_pct'].astype(int)


    return company_EBITA_growth['growth_pct'], N

# %%
def create_plot(EBITA_growth, period):
    plt.figure(figsize=(14, 8))

    N = period
    year_old = 2025 - N  
    year_new = 2025
    
    bins = np.arange(-100, 110, 10)
    plt.hist(EBITA_growth, bins=bins, edgecolor='black')
    
    
    plt.xlabel('Процент роста чистой прибыли (EBITA), %', fontsize=14)
    plt.xticks(np.arange(-100, 110, 10))
    plt.ylabel('Количество компаний', fontsize=14)
    plt.title(f'Распределение компаний по росту чистой прибыли\n{year_old} → {year_new} (период: {N})', fontsize=16)
    plt.grid(True)
    plt.axvline(x=0, color='red', linestyle='--', linewidth=1, label='Нулевой рост')
    plt.legend()
    
    mean_growth = EBITA_growth.median()
    plt.axvline(x=mean_growth, color='green', linestyle='-', linewidth=2, label=f'Медианный рост: {mean_growth:.1f}%')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
create_plot(*EBITA_growth(4))

# %%
create_plot(*EBITA_growth(3))

# %%
create_plot(*EBITA_growth(2))

# %%
create_plot(*EBITA_growth(1))

# %% [markdown]
# На основе графиков, где основным показателем является медианный рост, видно, что более половины компаний потеряла около 90 процентов своей чистой прибыли и этот спад прибыли сохраняется минимум на протяжениии четырёх лет.

# %%
df_city = company_EBITA_sortEBITA.head(500).copy()
df_city['lat'] = None
df_city['lon'] = None
df_city
# Out:
#                                                    name  \
# 2283  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИНКЕ...
# 7595  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УРАЛ...
# 7492  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УДС-...
# 5362  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СПЕЦ...
# 6935  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СТРО...
# ...                                                 ...
# 3339  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МОНТ...
# 387   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ " ОСК...
# 5812  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СТРО...
# 7634  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УРДЭ...
# 3317  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "МОНО...
#
#                                     city  EBITA_2021  EBITA_2022  EBITA_2023  \
# 2283                            Москва,    1012961.0     61583.0      4261.0
# 7595   Челябинская область, Магнитогорск         0.0         0.0         0.0
# 7492       Удмуртская Республика, Ижевск         0.0    253582.0   1032553.0
# 5362      Республика Дагестан, Махачкала  -1335209.0    905415.0   1502585.0
# 6935   Свердловская область, Березовский     12317.0     22056.0    236411.0
# ...                                  ...         ...         ...         ...
# 3339       Удмуртская Республика, Глазов    239395.0    180419.0      9814.0
# 387   Белгородская область, Старый Оскол     48699.0    124095.0     99312.0
# 5812                            Москва,      82259.0      4166.0    -27367.0
# 7634    Республика Саха (Якутия), Якутск         0.0     16591.0     -5879.0
# 3317          Иркутская область, Иркутск     40969.0     51417.0     38381.0
#
#       EBITA_2024  EBITA_2025   lat   lon
# 2283     23719.0   7061288.0  None  None
# 7595    -10972.0   6041650.0  None  None
# 7492   2997677.0   4571887.0  None  None
# 5362   -907394.0   3273561.0  None  None
# 6935    236846.0   3247384.0  None  None
# ...          ...         ...   ...   ...
# 3339    -39460.0     73733.0  None  None
# 387      97009.0     73675.0  None  None
# 5812     51943.0     73614.0  None  None
# 7634     19262.0     73214.0  None  None
# 3317     37156.0     73171.0  None  None
#
# [500 rows x 9 columns]

# %%
for city in df_city['city'].unique():
        location = geolocator.geocode(city)
        if location:
            df_city.loc[df_city['city'] == city, 'lat'] = location.latitude
            df_city.loc[df_city['city'] == city, 'lon'] = location.longitude
        else:
            print(f"Город '{city}' не найден.")
        time.sleep(1)
# Out:
# Город 'Иркутская область, Нукутский р-н' не найден.
# Город 'Республика Саха (Якутия), Намский у' не найден.
# Город 'Москва, Сосенское п' не найден.
# Город 'Красноярский край, БОЛЬШЕУЛУЙСКИЙ РАЙОН' не найден.

# %%
df_city_clean = pd.DataFrame()
df_city_clean = df_city.dropna().copy()
grouped = df_city_clean.groupby(['lat', 'lon']).agg({'name' : list, 'city' : list}).reset_index()
grouped['name_list'] = grouped['name'].apply(lambda x: '<br>'.join(x))

fig = px.scatter_map(grouped, lat='lat', lon='lon', hover_name='name_list', hover_data='city', zoom=3, height=500)
fig.update_layout(map_style='open-street-map')
fig.update_layout(margin={'r':0,'t':0,'l':0,'b':0})
fig.show()
